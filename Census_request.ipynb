# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
from census import Census
from us import states

# Census API Key
from config import api_key
years = [2010,2011,2012,2013,2014,2015,2016,2017,2018,2019]

# %%
def simple_county_names (name):
    name = name.replace(", California","")
    return name

# %%
for year in years:
    c = Census(api_key, year=year)
    variables = ('B01003_001E', 'B17001_002E','NAME')
    request = c.acs5.state_county(variables, '06', Census.ALL)

    # census_data = c.sf1.state_county_tract('NAME', '06', Census.ALL)

    census_df = pd.DataFrame(request)

    census_df = census_df.rename(columns={"B01003_001E": "Population",
                                      "B17001_002E": "Poverty Count",
                                      "NAME": "Name", "county": "County"})

    # Add in Poverty Rate (Poverty Count / Population)
    census_df["Poverty Rate"] = 100 * \
        census_df["Poverty Count"].astype(int) / census_df["Population"].astype(int)

    # Final DataFrame
    new_names = []
    census_df = census_df[["Name","Population", "Poverty Count", "Poverty Rate", "County"]]
    
    for name in census_df["Name"]:
        new_name = simple_county_names(name)
        new_names.append(new_name)
    
    census_df["Name"] = new_names
    census_df.sort_values("County", inplace=True)
    census_df.to_csv(f"Census_csvs/{year}_census_data_ca_county.csv", encoding="utf-8", index=False)

# %%
census_df
# Out:
#                       Name  Population  Poverty Count  Poverty Rate County
# 48          Alameda County   1656754.0       161581.0      9.752866    001
# 17           Alpine County      1039.0          205.0     19.730510    003
# 42           Amador County     38429.0         3451.0      8.980197    005
# 29            Butte County    225817.0        41974.0     18.587617    007
# 37        Calaveras County     45514.0         5147.0     11.308608    009
# 27           Colusa County     21454.0         2774.0     12.929990    011
# 3      Contra Costa County   1142251.0        98595.0      8.631641    013
# 57        Del Norte County     27495.0         4760.0     17.312239    015
# 11        El Dorado County    188563.0        15643.0      8.295901    017
# 33           Fresno County    984521.0       218254.0     22.168547    019
# 28            Glenn County     27976.0         4818.0     17.221904    021
# 16         Humboldt County    135940.0        26674.0     19.621892    023
# 47         Imperial County    180701.0        41100.0     22.744755    025
# 4              Inyo County     17977.0         1635.0      9.094955    027
# 34             Kern County    887641.0       179980.0     20.276215    029
# 30            Kings County    150691.0        24725.0     16.407748    031
# 43             Lake County     64195.0        11753.0     18.308279    033
# 45           Lassen County     30818.0         2830.0      9.182945    035
# 54      Los Angeles County  10081570.0      1480446.0     14.684677    037
# 18           Madera County    155433.0        29273.0     18.833195    039
# 23            Marin County    259943.0        18349.0      7.058855    041
# 1          Mariposa County     17420.0         2616.0     15.017222    043
# 53        Mendocino County     87224.0        15251.0     17.484867    045
# 0            Merced County    271382.0        56217.0     20.715081    047
# 2             Modoc County      8907.0         1618.0     18.165488    049
# 8              Mono County     14310.0         1713.0     11.970650    051
# 12         Monterey County    433410.0        54393.0     12.550010    053
# 49             Napa County    139623.0        10614.0      7.601899    055
# 52           Nevada County     99244.0        10844.0     10.926605    057
# 35           Orange County   3168044.0       340048.0     10.733689    059
# 24           Placer County    385512.0        29588.0      7.674988    061
# 31           Plumas County     18660.0         2224.0     11.918542    063
# 21        Riverside County   2411439.0       325279.0     13.489000    065
# 10       Sacramento County   1524553.0       220713.0     14.477227    067
# 9        San Benito County     60376.0         5061.0      8.382470    069
# 22   San Bernardino County   2149031.0       333613.0     15.523880    071
# 14        San Diego County   3316073.0       374787.0     11.302134    073
# 13    San Francisco County    874961.0        89030.0     10.175311    075
# 41      San Joaquin County    742603.0       105461.0     14.201532    077
# 32  San Luis Obispo County    282165.0        33261.0     11.787784    079
# 39        San Mateo County    767423.0        51085.0      6.656694    081
# 6     Santa Barbara County    444829.0        57556.0     12.938905    083
# 55      Santa Clara County   1927470.0       142534.0      7.394875    085
# 19       Santa Cruz County    273962.0        34419.0     12.563421    087
# 25           Shasta County    179212.0        29423.0     16.417985    089
# 50           Sierra County      3040.0          291.0      9.572368    091
# 56         Siskiyou County     43468.0         8102.0     18.638999    093
# 26           Solano County    441829.0        41121.0      9.306994    095
# 46           Sonoma County    499772.0        45418.0      9.087744    097
# 5        Stanislaus County    543194.0        81415.0     14.988199    099
# 38           Sutter County     96109.0        14687.0     15.281607    101
# 7            Tehama County     63912.0        13930.0     21.795594    103
# 20          Trinity County     12700.0         2372.0     18.677165    105
# 15           Tulare County    461898.0       108512.0     23.492633    107
# 40         Tuolumne County     54045.0         6443.0     11.921547    109
# 36          Ventura County    847263.0        74645.0      8.810133    111
# 51             Yolo County    217352.0        39919.0     18.366061    113
# 44             Yuba County     76360.0        11572.0     15.154531    115
